# %%
# Write a Python program that checks if a given number is even. If it is, print "Even number".

n = 8
if n%2==0 :
  print("n is even")
else:
  print("n is odd")
# Out:
# n is even

# %%
# Write a Python program that checks if a given string contains the letter 'a'. If it does, print "String contains 'a'"

str1 = "A"
if "a" or "A" in str1:
  print("str1 has a")
else:
  print("str1 does not have a")
# Out:
# str1 has a

# %%
# Write a Python program that checks if a given year is a leap year. If it is, print "Leap year"

n = 2000
if (n%4==0 and n%100!=0) or n%400==0:
  print("it is a leap year")
else:
  print("not a leap year")
# Out:
# it is a leap year

# %%
# Write a Python program that checks if a given number is positive. If it is, print "Positive number

n = -5
if n >= 0:
  print("Number is positive")
else:
  print("Numnber is negative")
# Out:
# Numnber is negative

# %%
# Write a Python program that checks if a given character is a vowel. If it is, print "Vowel"

Str1 = "b"
if "a" or "e" or "i" or "o" or "u" in Str1:
  print("It is vowel")
else:
  print("It is not a vowel")
# Out:
# It is vowel
