# %% [markdown]
# Question 1: Creating DataFrame
# Create a DataFrame named df with the following data:

# %%
import pandas as pd
data = {'Name': ['John', 'Anna', 'Peter', 'Linda'],
        'Age': [28, 35, 29, 42],
        'City': ['New York', 'Paris', 'Berlin', 'London']}
df = pd.DataFrame(data)

# %% [markdown]
# Print the DataFrame df.

# %% [markdown]
# Question 2: Accessing DataFrame
# Given the DataFrame df from Question 1, access and print the first two rows.
#
# Question 3: Shape of DataFrame
# Given the DataFrame df from Question 1, print the shape of the DataFrame.
#
# Question 4: Data Types
# Given the DataFrame df from Question 1, print the data types of each column.
#
# Question 5: Summary Statistics
# Given the DataFrame df from Question 1, print the summary statistics (mean, min, max, etc.) for numeric columns.
#
# Question 6: Adding a New Column
# Given the DataFrame df from Question 1, add a new column named 'Gender' with values ['Male', 'Female', 'Male', 'Female'].
#
# Question 7: Filtering Data
# Given the DataFrame df from Question 1, filter and print the rows where Age is greater than 30.
#
# Question 8: Sorting Data
# Given the DataFrame df from Question 1, sort the DataFrame by Age in descending order and print the result.

# %%
#Q2.
df.head(2)
# Out:
#    Name  Age      City
# 0  John   28  New York
# 1  Anna   35     Paris

# %%
#Q#.
df.shape
# Out:
# (4, 3)

# %%
#Q4.
df.dtypes
# Out:
# Name    object
# Age      int64
# City    object
# dtype: object

# %%
#Q5.
summary = df.describe(include = 'all')
summary
# Out:
#         Name        Age      City
# count      4   4.000000         4
# unique     4        NaN         4
# top     John        NaN  New York
# freq       1        NaN         1
# mean     NaN  33.500000       NaN
# std      NaN   6.454972       NaN
# min      NaN  28.000000       NaN
# 25%      NaN  28.750000       NaN
# 50%      NaN  32.000000       NaN
# 75%      NaN  36.750000       NaN
# max      NaN  42.000000       NaN

# %%
#Q6.
DataFrame.insert(column= 'Gender')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-6e23a6b60d28> in <cell line: 2>()
#       1 #Q6.
# ----> 2 DataFrame.insert(column= 'Gender')
#
# NameError: name 'DataFrame' is not defined

# %%
df
# Out:
#     Name  Age      City
# 0   John   28  New York
# 1   Anna   35     Paris
# 2  Peter   29    Berlin
# 3  Linda   42    London

# %%
df['gender']=["male","female","male","male"]

# %%
df
# Out:
#     Name  Age      City  gender
# 0   John   28  New York    male
# 1   Anna   35     Paris  female
# 2  Peter   29    Berlin    male
# 3  Linda   42    London    male

# %%
#Q7.
print(df[df['Age']>30])
# Out:
#     Name  Age    City  gender
# 1   Anna   35   Paris  female
# 3  Linda   42  London    male

# %%
#Q8.
sorted_df= df.sort_values(by= 'Age', ascending=False)
print(sorted_df)
# Out:
#     Name  Age      City  gender
# 3  Linda   42    London    male
# 1   Anna   35     Paris  female
# 2  Peter   29    Berlin    male
# 0   John   28  New York    male

# %% [markdown]
# df.loc()
# df.iloc()

# %%
df.iloc[1:20]
