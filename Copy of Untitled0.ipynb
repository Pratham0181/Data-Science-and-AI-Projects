# %%
# Write a python program to take two numbers as input from the user and display their sum.

num1= int(input("Enter 1st num = "))
num2= int(input("Enter 2nd num = "))

add= num1+num2
print(add)
# Out:
# Enter 1st num = 12
# Enter 2nd num = 20
# 32

# %%
# Calculate and print the midpoint of two numbers entered by the user.

# %%
# Write a Python program to calculate the area of a triangle using the formula: area = 0.5 * base * height.

base= int(input("Enter base of triangle = "))
height= int(input("Enter height of triangle = "))

area= 0.5*base*height

print("Area of triangle is = ", area)
# Out:
# Enter base of triangle80
# Enter height of triangle70
# Area of triangle is =  2800.0

# %%
# Take three numbers as input from the user and display their product

num1= int(input("Enter Num1 = "))
num2= int(input("Enter Num2 = "))
num3= int(input("Enter Num3 = "))

mul= num1*num2*num3

print("Product of three numbers is = ", mul)
# Out:
# Enter Num1 = 10
# Enter Num2 = 20
# Enter Num3 = 50
# Product of three numbers is =  10000

# %%
# Take a number as input and display its square and cube.

num1= int(input("Enter Num1 = "))

square= num1*num1
cube= num1**3

print("The square and cube of num is = ", square, cube)
# Out:
# Enter Num1 = 2
# The square and cube of num is =  4 8

# %%
# Take two numbers as input and display their quotient and remainder.

A = int(input('A : '))
B = int(input('B : '))

Q = A//B

R = A%B

print('Quotient: ', Q)
print('Remainder: ', R)
# Out:
# A : 9
# B : 2
# Quotient:  4
# Remainder:  1

# %%
# Take three numbers as input and display their average

A = int(input("Enter A = "))
B = int(input("Enter B = "))
C = int(input("Enter C = "))

Avg= (A+B+C)/3

print(Avg)
# Out:
# Enter A = 2
# Enter B = 3
# Enter C = 5
# 3.3333333333333335

# %%
# Write a Python program to calculate the area of a rectangle using the formula: area = length * width.
