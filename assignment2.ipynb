# %%
my_list = [1,2,3,4]
my_list2 = [1,2,'Abhi',12.5]

# %%
my_list = [1,2,3,4]
my_list2 = [1,2,'Abhi',12.5]

# %%
loss_functions = ['Mean Absolute Error', 'MSE', 'abhi','HL','LL']

# %%
loss_functions[1][0]
# Out:
# 'M'
